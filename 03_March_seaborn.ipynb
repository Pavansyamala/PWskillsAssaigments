# %% [raw]
# #Q1)
#
# Seaborn is a library to plot the graphs
#
# relational plots
# scatter
# hist
# bar
# box

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from seaborn import load_dataset

# %%
data = load_dataset('fmri')

# %%
x = data['timepoint']
y = data['signal']

# %%
sns.relplot(data = data , x = 'timepoint' , y = 'signal' , kind='line')
plt.show()
# Out:
# D:\Anaconda_Installation\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data2 = load_dataset('titanic')

# %%
sns.boxenplot(data = data2 , x = 'pclass' , y = 'age')
plt.show()

# %%
sns.boxenplot(data = data2 , x = 'pclass' , y = 'fare')
plt.show()

# %%
data3 = load_dataset('diamonds')

# %%
sns.histplot(data = data3 , x='price' , hue='cut')
plt.show()
